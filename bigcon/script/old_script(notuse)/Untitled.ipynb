# %% [markdown]
# ### 전기차 충전소 데이터 가져오기
#
# ev monitor 사이트에서 받아온 전기차 충전기 데이터.
# 운영기관	충전소	충전기ID	충전기타입	지역	시군구	주소	이용가능시간	이용자 제한	충전용량
#
# 용인시의 충전소 데이터를 추출한 다음 동별로 groupby해서 동별 충전소 지수를 반영할 예정

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np

# %%
# def geocoding(address):
#     geolocoder = Nominatim(user_agent = 'South Korea', timeout=None)
#     geo = geolocoder.geocode(address)
#     try :
#         crd = {"lat": str(geo.latitude), "lng": str(geo.longitude)}
#     except :
#         crd = np.nan
#         print(address)
        
#     return crd

# %%
path = 'C:/2022빅콘테스트_데이터분석리그_데이터분석분야_챔피언부문_데이터셋_220908/자료/'
ev_cg = pd.read_excel(path + '충전소 리스트.xlsx')
ev_cg.head()
# Out:
#    충전소 목록 [2022-09-16]                   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                  NaN                          NaN        NaN        NaN
# 1                 운영기관                          충전소      충전기ID      충전기타입
# 2       환경부(한국자동차환경협회)                  신북보건지소공영주차장         21       DC콤보
# 3       환경부(한국자동차환경협회)                  신북보건지소공영주차장         22       DC콤보
# 4       환경부(한국자동차환경협회)   한국생산기술연구원 대경본부바이오메디칼생산기술센터         01       DC콤보
#
#   Unnamed: 4 Unnamed: 5              Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN                     NaN        NaN        NaN
# 1         지역        시군구                      주소     이용가능시간     이용자 제한
# 2      전라남도        영암군   전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능        NaN
# 3      전라남도        영암군   전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능        NaN
# 4      경상북도        영천시          경상북도 영천시 양호길 59  24시간 이용가능        NaN
#
#     Unnamed: 9 Unnamed: 10
# 0          NaN         NaN
# 1         충전용량          비고
# 2  급속(200kW동시)         NaN
# 3  급속(200kW동시)         NaN
# 4  급속(100kW단독)         NaN

# %%
cols = ev_cg.iloc[1,:]
ev_cg = ev_cg[2:]
ev_cg.columns = cols
ev_cg.head()
# Out:
# 1            운영기관                          충전소 충전기ID 충전기타입     지역   시군구  \
# 2  환경부(한국자동차환경협회)                  신북보건지소공영주차장    21  DC콤보  전라남도   영암군
# 3  환경부(한국자동차환경협회)                  신북보건지소공영주차장    22  DC콤보  전라남도   영암군
# 4  환경부(한국자동차환경협회)   한국생산기술연구원 대경본부바이오메디칼생산기술센터    01  DC콤보  경상북도   영천시
# 5  환경부(한국자동차환경협회)   한국생산기술연구원 대경본부바이오메디칼생산기술센터    02  DC콤보  경상북도   영천시
# 6  환경부(한국자동차환경협회)                (구)거진수산센터 주차장    11  DC콤보   강원도   고성군
#
# 1                      주소     이용가능시간 이용자 제한         충전용량   비고
# 2  전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능    NaN  급속(200kW동시)  NaN
# 3  전라남도 영암군 신북면 간은정로 21-7  24시간 이용가능    NaN  급속(200kW동시)  NaN
# 4         경상북도 영천시 양호길 59  24시간 이용가능    NaN  급속(100kW단독)  NaN
# 5         경상북도 영천시 양호길 59  24시간 이용가능    NaN  급속(100kW단독)  NaN
# 6   강원도 고성군 거진읍 거진리 22-93  24시간 이용가능    NaN  급속(200kW동시)  NaN

# %%
ev_cg = ev_cg[ev_cg['시군구'].str.contains('^용인시',na = False)]

# %%
ev_cg
# Out:
# 1                 운영기관                 충전소 충전기ID            충전기타입    지역   시군구  \
# 746     환경부(한국자동차환경협회)             구성동주민센터    01             DC콤보  경기도   용인시
# 747     환경부(한국자동차환경협회)             구성동주민센터    02             DC콤보  경기도   용인시
# 1044    환경부(한국자동차환경협회)             금학공영주차장    11             DC콤보  경기도   용인시
# 1045    환경부(한국자동차환경협회)             금학공영주차장    12             DC콤보  경기도   용인시
# 1074    환경부(한국자동차환경협회)         기흥휴게소(부산방향)    01  DC차데모+AC3상+DC콤보  경기도   용인시
# ...                ...                 ...   ...              ...   ...   ...
# 137837          한국전자금융              용인세정상가    01             AC완속  경기도   용인시
# 137838          한국전자금융              용인세정상가    02             AC완속  경기도   용인시
# 138342            중앙제어  삼성 인력개발원 창조관(출입제한)    01             DC콤보  경기도   용인시
# 138343            중앙제어  삼성 인력개발원 창조관(출입제한)    02             DC콤보  경기도   용인시
# 138344            중앙제어  삼성 인력개발원 창조관(출입제한)    03             AC완속  경기도   용인시
#
# 1                                                      주소     이용가능시간  \
# 746                                경기도 용인시 기흥구 구성로77번길 17  24시간 이용가능
# 747                                경기도 용인시 기흥구 구성로77번길 17  24시간 이용가능
# 1044                                  경기도 용인시 처인구 용문로 140  24시간 이용가능
# 1045                                  경기도 용인시 처인구 용문로 140  24시간 이용가능
# 1074                            경기도 용인시 기흥구 공세로 173 (공세동)  24시간 이용가능
# ...                                                   ...        ...
# 137837                 경기도 용인시 기흥구 흥덕2로75번길 29-8(영덕동 996)  24시간 이용가능
# 137838                 경기도 용인시 기흥구 흥덕2로75번길 29-8(영덕동 996)  24시간 이용가능
# 138342  경기도 용인시 처인구 포곡읍 에버랜드로562번길 10-16삼성 인력개발원 창조관(출...  24시간 이용가능
# 138343  경기도 용인시 처인구 포곡읍 에버랜드로562번길 10-16삼성 인력개발원 창조관(출...  24시간 이용가능
# 138344  경기도 용인시 처인구 포곡읍 에버랜드로562번길 10-16삼성 인력개발원 창조관(출...  24시간 이용가능
#
# 1                 이용자 제한         충전용량     비고
# 746                  NaN  급속(100kW단독)  1시간무료
# 747                  NaN  급속(100kW단독)  1시간무료
# 1044                 NaN  급속(200kW동시)    NaN
# 1045                 NaN  급속(200kW동시)    NaN
# 1074                 NaN     급속(50kW)    NaN
# ...                  ...          ...    ...
# 137837               NaN          7kW    NaN
# 137838               NaN          7kW    NaN
# 138342  직원 및 업무용차량 출입 제한        100kW    NaN
# 138343  직원 및 업무용차량 출입 제한        100kW    NaN
# 138344  직원 및 업무용차량 출입 제한          7kW    NaN
#
# [4017 rows x 11 columns]

# %%
address
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38124/1739064490.py in <module>
# ----> 1 address
#
# NameError: name 'address' is not defined

# %%
ev_cg.to_csv(path + '용인시 충전소.csv',encoding= 'EUC-KR')

# %%
doro = list(map(lambda x: x.split(),address))

# %%
doro

# %%
def help_func(lst):
    if len(lst) == 0: return np.nan
    
    if "로" in lst[0]:
        return lst[0]
    else : 
        lst = lst[1:]
        return help_func(lst)

# %%
list(map(help_func,doro))

# %%
doro_address = pd.read_table(path + '주소_경기도.txt',sep = '|',encoding = 'EUC-KR',header = None)
old_address = pd.read_table(path + '지번_경기도.txt',sep = '|',encoding = 'EUC-KR',header = None)

# %%
old_address = old_address[old_address[4].str.contains('용인시')]
doro_address = doro_address[doro_address[4].str.contains('용인시')]rnaddrkor_gyunggi.txt

# %%
doro_old = pd.read_table(path + 'rnaddrkor_gyunggi.txt', sep = '|', encoding = 'CP949', header = None)
# Out:
# C:\Users\ghrbs\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
old_address
# Out:
#                                0   1           2    3        4    5    6   7   \
# 56311   4111710200101820001053054   1  4146311100  경기도  용인시 기흥구  영덕동  NaN   0
# 56312   4111710200101820001053054   4  4146311100  경기도  용인시 기흥구  영덕동  NaN   0
# 56313   4111710200101820001053054   5  4146311100  경기도  용인시 기흥구  영덕동  NaN   0
# 56577   4111710200102790001053054   1  4146311100  경기도  용인시 기흥구  영덕동  NaN   0
# 57082   4111710200106010002000001   1  4146311100  경기도  용인시 기흥구  영덕동  NaN   0
# ...                           ...  ..         ...  ...      ...  ...  ...  ..
# 641256  4146510700200560005000001   1  4146510700  경기도  용인시 수지구  상현동  NaN   0
# 641257  4146510700200820001000472   1  4146510700  경기도  용인시 수지구  상현동  NaN   0
# 641258  4146510700200820001000472   2  4146510700  경기도  용인시 수지구  상현동  NaN   0
# 641259  4146510700200820001000472   3  4146510700  경기도  용인시 수지구  상현동  NaN   0
# 641260  4146510700200820006000482   1  4146510700  경기도  용인시 수지구  상현동  NaN   0
#
#           8   9   10
# 56311   1288   0   1
# 56312   1287   0   0
# 56313   1286   0   0
# 56577   1293   0   1
# 57082   1273   0   1
# ...      ...  ..  ..
# 641256  1190   2   1
# 641257   414   2   1
# 641258   414   4   0
# 641259   414   7   0
# 641260   414   9   1
#
# [76426 rows x 11 columns]

# %%
doro_address
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38124/3931324035.py in <module>
# ----> 1 doro_address
#
# NameError: name 'doro_address' is not defined
